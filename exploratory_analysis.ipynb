# %% [markdown]
# # Replicating Kdensity

# %%
from sklearn.datasets import fetch_species_distributions
from mpl_toolkits
data = fetch_species_distributions()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/upar/Library/CloudStorage/OneDrive-UniversidaddelosAndes/00 SCHOOL/0-Semesters Archive/2022-20/5-Taller_ARCGIS-GIS/2-Evaluaciones/Proyecto_final/estratos_y_el_espacio_bogotano/exploratory_analysis.ipynb Cellule 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/upar/Library/CloudStorage/OneDrive-UniversidaddelosAndes/00%20SCHOOL/0-Semesters%20Archive/2022-20/5-Taller_ARCGIS-GIS/2-Evaluaciones/Proyecto_final/estratos_y_el_espacio_bogotano/exploratory_analysis.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.datasets import fetch_species_distributions
# ...

# %%
# Out:
# {'coverages': array([[[ -128,  -128,  -128, ...,  -128,  -128,  -128],
#          [ -128,  -128,  -128, ...,  -128,  -128,  -128],
#          [ -128,  -128,  -128, ...,  -128,  -128,  -128],
#          ...,
#          [ -128,  -128,  -128, ...,  -128,  -128,  -128],
#          [ -128,  -128,  -128, ...,  -128,  -128,  -128],
#          [ -128,  -128,  -128, ...,  -128,  -128,  -128]],
#
#         [[-9999, -9999, -9999, ..., -9999, -9999, -9999],
#          [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#          [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#          ...,
#          [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#          [-9999, -9999, -9999, ..., -9999, -9999, -9999],
#          [-9999, -9999, -9999, ..., -9999, -9999, -9999]],
#
#         [[ -128,  -128,  -128, ...,  -128,  -128,  -128],
#          [ -128,  -128,  -128, ...,  -128,  -128,  -128],
#          [ -128,  -128,  -128, ...,  -128,  -128,  -128],
#          ...,
# ...
